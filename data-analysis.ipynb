# %%
import numpy as np
import pandas as pd
import scipy.io as io
np.set_printoptions(
    precision=1,      # Number of decimal places
    suppress=True,    # Suppress scientific notation (e.g., 1e-4 becomes 0.0001)
    linewidth=200,    # Number of characters per line before wrapping
    threshold=100      # Total number of elements to show before truncating with '...'
    # Use threshold=np.inf to print the ENTIRE array (be careful with huge arrays!)
)

# %%
mat_data = io.loadmat('refs/Antonella Branda/Problems/problem800.mat')

# %%
mat_data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'CL', 'M', 'N', 'P', 'R', 'RD', 'R_DD', 'TF', 'TPO', 'V', 'Z', 'a', 'b', 'beta', 'd', 'eta', 'filename', 'i', 'k', 'm', 'mu_DD', 's', 'v', 'w'])

# %%
pd.DataFrame(mat_data['TPO'])
# Out:
#            0           1           2           3           4           5   \
# 0  101.889681  100.750904   72.883571  109.733485   87.736976  103.522863
# 1   43.848131  115.870254  129.326167  110.510867  100.885825  119.555153
# 2   96.313092  100.826259   88.537348  123.105310   99.506543  116.885225
# 3   62.153305   89.535371   91.737523  111.686598  111.279667   94.099555
# 4   69.937923  108.473412   97.099256   86.819296   93.915678  108.179861
#
#            6           7           8           9   ...          35  \
# 0   95.449788  121.676646   95.493313  120.038212  ...   69.421935
# 1  129.943215   98.937255  145.229696  120.770971  ...  134.895007
# 2  107.040994   70.073718  130.132546  106.032329  ...  107.485130
# 3  110.732754  110.054458  127.914050   80.732468  ...  104.940305
# 4  109.222490  148.177045  117.392653   43.250924  ...   86.462487
#
#            36          37          38          39          40          41  \
# ...
